# %% [markdown]
# <a href="https://colab.research.google.com/github/RasonYudha4/AI-Subject/blob/main/self-taught/Train_test_split.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("carprices.csv")
df.head()
# Out:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.xlabel('Mileage')
plt.ylabel('Sell Price($)')
plt.scatter(df['Mileage'],df['Sell Price($)'])

# %%
plt.scatter(df['Age(yrs)'],df['Sell Price($)'])

# %%
X = df[['Mileage','Age(yrs)']]
y = df['Sell Price($)']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)

# %%
X_train
# Out:
#     Mileage  Age(yrs)
# 16    28000         2
# 8     91000         8
# 19    52000         5
# 10    83000         7
# 12    59000         5
# 2     57000         5
# 17    69000         5
# 1     35000         3
# 5     59000         5
# 15    25400         3
# 0     69000         6
# 6     52000         5
# 9     67000         6
# 7     72000         6

# %%
X_test
# Out:
#     Mileage  Age(yrs)
# 4     46000         4
# 18    87600         8
# 13    58780         4
# 11    79000         7
# 14    82450         7
# 3     22500         2

# %%
y_train
# Out:
# 16    35500
# 8     12000
# 19    28200
# 10    18700
# 12    26000
# 2     26100
# 17    19700
# 1     34000
# 5     26750
# 15    35000
# 0     18000
# 6     32000
# 9     22000
# 7     19300
# Name: Sell Price($), dtype: int64

# %%
y_test
# Out:
# 4     31500
# 18    12800
# 13    27500
# 11    19500
# 14    19400
# 3     40000
# Name: Sell Price($), dtype: int64

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
clf = model.predict(X_test)
clf
# Out:
# array([29678.29750479, 15204.87727531, 24142.02983854, 18043.47632335,
#        16548.94397213, 38084.64163353])

# %%
model.score(X_test,y_test)
# Out:
# 0.929120020262362
